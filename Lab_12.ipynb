# %%
def reservation_status(
   passenger_name,
   ticket_status="Confirmed"):
   print("Passenger Name :", passenger_name)
   print("Ticket Status :", ticket_status)

# %%
reservation_status("Rahul Sharma")
reservation_status("Amit Verma", "Waiting")
# Out:
# Passenger Name : Rahul Sharma
# Ticket Status : Confirmed
# Passenger Name : Amit Verma
# Ticket Status : Waiting

# %%
def passenger_booking(*passengers):
   print("Passenger List:")
   for name in passengers:
       print("Passenger :", name)

passenger_booking(
   "Rahul Sharma",
   "Priya Singh",
   "Amit Verma",
   "Neha Kapoor")
# Out:
# Passenger List:
# Passenger : Rahul Sharma
# Passenger : Priya Singh
# Passenger : Amit Verma
# Passenger : Neha Kapoor

# %%
def ticket_details(**details):
   print("Ticket Information:")
   for key, value in details.items():
       print(key, ":", value)

ticket_details(
   passenger_name="Rahul Sharma",
   train_name="Rajdhani Express",
   seat_number="B1-21",
   fare=2500,
   status="Confirmed")
# Out:
# Ticket Information:
# passenger_name : Rahul Sharma
# train_name : Rajdhani Express
# seat_number : B1-21
# fare : 2500
# status : Confirmed

# %%
def seat_countdown(seats):
   if seats == 0:
       print("All Seats Booked")
       return
   print("Remaining Seats :", seats)
   seat_countdown(seats - 1)

seat_countdown(5)
# Out:
# Remaining Seats : 5
# Remaining Seats : 4
# Remaining Seats : 3
# Remaining Seats : 2
# Remaining Seats : 1
# All Seats Booked

# %%
def verify_passenger(passenger_number):
   if passenger_number == 0:
       print("Verification Completed")
       return
   print("Verifying Passenger :", passenger_number)
   verify_passenger(passenger_number - 1)

verify_passenger(3)
# Out:
# Verifying Passenger : 3
# Verifying Passenger : 2
# Verifying Passenger : 1
# Verification Completed

# %%
def final_booking(
   train_name="Rajdhani Express",
   *seat_numbers
):
   print("===================================")
   print(" Railway Reservation ")
   print("===================================")
   print("Train Name :", train_name)
   for seat in seat_numbers:
       print("Allocated Seat :", seat)

final_booking(
   "Rajdhani Express",
   "B1-21",
   "B1-22",
   "B1-23")
# Out:
# ...
#  Railway Reservation
# ...
# Train Name : Rajdhani Express
# Allocated Seat : B1-21
# Allocated Seat : B1-22
# Allocated Seat : B1-23

# %%
def seat_countdown(seats):
    if seats <= 0:
        print("All Seats Booked")
        return

    print("Remaining Seats:", seats)

    booked = int(input("Enter number of seats to book: "))

    if booked > seats:
        print(f"Cannot book {booked} seats. Only {seats} remaining.\n")
        seat_countdown(seats)
    elif booked <= 0:
        print("Please enter a valid number of seats.\n")
        seat_countdown(seats)
    else:
        seat_countdown(seats - booked)


total_limit = int(input("Set total seat limit for the event: "))
seat_countdown(total_limit)
# Out:
# Set total seat limit for the event: 3
# Remaining Seats: 3
# Enter number of seats to book: 45
# Cannot book 45 seats. Only 3 remaining.
#
# Remaining Seats: 3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3187/4173806407.py in <cell line: 0>()
#      19
#      20 total_limit = int(input("Set total seat limit for the event: "))
# ---> 21 seat_countdown(total_limit)
#
# /tmp/ipykernel_3187/4173806407.py in seat_countdown(seats)
#      10     if booked > seats:
#      11         print(f"Cannot book {booked} seats. Only {seats} remaining.\n")
# ---> 12         seat_countdown(seats)
#      13     elif booked <= 0:
#      14         print("Please enter a valid number of seats.\n")
#
# /tmp/ipykernel_3187/4173806407.py in seat_countdown(seats)
#       6     print("Remaining Seats:", seats)
#       7
# ...

# %%
TOTAL_SEATS = 100
def seat_countdown(seats):
    if seats <= 0:
        print("All Seats Booked")
        return
    print("Remaining Seats:", seats)
    booked = int(input("Enter number of seats to book: "))
    if booked > seats:
        print(f"Cannot book {booked} seats. Only {seats} remaining.\n")
        seat_countdown(seats)
    elif booked <= 0:
        print("Please enter a valid number of seats.\n")
        seat_countdown(seats)
    else:
        seat_countdown(seats - booked)
seat_countdown(TOTAL_SEATS)

# %%
TOTAL_SEATS = 100
def seat_countdown(seats):
    if seats <= 0:
        print("All Seats Booked")
        return
    print("Remaining Seats:", seats)
    booked = int(input("Enter number of seats to book: "))
    if booked > seats:
        print(f"Cannot book {booked} seats. Only {seats} remaining.\n")
        seat_countdown(seats)
    elif booked <= 0:
        print("Please enter a valid number of seats.\n")
        seat_countdown(seats)
    else:
        seat_countdown(seats - booked)
seat_countdown(TOTAL_SEATS)
# Out:
# Remaining Seats: 100
# Enter number of seats to book: 50
# Remaining Seats: 50
# Enter number of seats to book: 38
# Remaining Seats: 12
# Enter number of seats to book: 17
# Cannot book 17 seats. Only 12 remaining.
#
# Remaining Seats: 12
